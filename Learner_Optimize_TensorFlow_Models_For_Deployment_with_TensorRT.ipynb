# %% [markdown]
# <a href="https://colab.research.google.com/github/dingkwang/Optimize-TensorFlow-Models-For-Deployment-with-TensorRT/blob/master/Learner_Optimize_TensorFlow_Models_For_Deployment_with_TensorRT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align=center> Optimize TensorFlow Models For Deployment with TensorRT</h2>

# %% [markdown]
# In this project, you will learn how to use the TensorFlow integration for TensorRT (also known as TF-TRT) to increase inference performance.

# %% [markdown]
# ### Learning Objectives

# %% [markdown]
# By the time you complete this project, you will be able to:
#
# - Optimize Tensorflow models using TF-TRT
# - Use TF-TRT to optimize several deep learning models at FP32, FP16, and INT8 precision
# - Observe how tuning TF-TRT parameters affects performance and inference throughput

# %% [markdown]
# ### Prerequisites

# %% [markdown]
# In order to be successful with this project, it is assumed you are:
#
# - Competent in the Python programming language
# - Familiar with Deep Learning, and understand what **inference** is
# - Familiar with TensorFlow, and its Keras API

# %% [markdown]
# ### Contents

# %% [markdown]
# This project/notebook consists of several Tasks.
#
# - **[Task 1]()**: Introduction to the Project.
# - **[Task 2]()**: Setup your TensorFlow and TensorRT Runtime
# - **[Task 3]()**: Load the Data and Pre-trained Model
# - **[Task 4]()**: Create Batched Input
# - **[Task 5]()**: Load TensorFlow SavedModel
# - **[Task 6]()**: Get Baseline for Prediction Throughput and Accuracy
# - **[Task 7]()**: Convert a TensorFlow saved model into a TF-TRT Float32 Optimized Graph
# - **[Task 8]()**: Benchmark TF-TRT Float32
# - **[Task 9]()**: Convert to TF-TRT Float16 and Benchmark
# - **[Task 10]()**: TF-TRT INT8 Model
# - **[Task 11]()**: Converting to TF-TRT INT8
# - **[Task 12]()**: Benchmark TF-TRT INT8

# %% [markdown]
# ## Task 2: Setup your TensorFlow and TensorRT Runtime.

# %% [markdown]
# You will only be able to use the Colab Notebook after you save it to your Google Drive folder. Click on the File menu and select “Save a copy in Drive…
#
# ![Copy to Drive](https://drive.google.com/uc?id=1CH3eDmuJL8WR0AP1r3UE6sOPuqq8_Wl7)

# %% [markdown]
# ## Check GPU Availability
#
# Check if your Colab notebook is configured to use Graphical Processing Units (GPUs). If zero GPUs are available, check if the Colab notebook is configured to use GPUs (Menu > Runtime > Change Runtime Type).
#
# ![Hardware Accelerator Settings](https://drive.google.com/uc?id=1qrihuuMtvzXJHiRV8M7RngbxFYipXKQx)

# %%
# !nvidia-smi
# Out:
# Wed Apr 19 08:19:40 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.10   Driver Version: 470.141.10   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A6000    On   | 00000000:05:00.0 Off |                  Off |
# | 30%   35C    P8    28W / 300W |   1090MiB / 48682MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1877      G   /usr/lib/xorg/Xorg                174MiB |
# |    0   N/A  N/A      2413      G   /usr/bin/gnome-shell               20MiB |
# |    0   N/A  N/A    286193      G   ...mviewer/tv_bin/TeamViewer       71MiB |
# |    0   N/A  N/A    610052      G   /usr/lib/xorg/Xorg                278MiB |
# |    0   N/A  N/A    610303      G   /usr/lib/xorg/Xorg                 70MiB |
# |    0   N/A  N/A    610421      G   ...mviewer/tv_bin/TeamViewer      148MiB |
# |    0   N/A  N/A    620648      G   ...veSuggestionsOnlyOnDemand       73MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Install TensorFlow-GPU 2.0 and TensorRT Runtime

# %%
# %%bash
#
# # sudo apt-key adv --fetch-keys http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64/7fa2af80.pub
#
# # wget -q https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64/nvidia-machine-learning-repo-ubuntu1804_1.0.0-1_amd64.deb
#
# # dpkg -i nvidia-machine-learning-repo-*.deb
# apt-get -qq update
# sudo apt-get install tensorrt=8.5.1.7-1+cuda11.8
#
# python --version
# # sudo apt-get -qq install libnvinfer6=6.0.1-1
# # sudo apt-get -qq install cuda10.1
# # sudo apt-get -qq install libnvinfer6=6.0.1-1+cuda10.1 # libnvinfer5
# # sudo apt-get install # libnvinfer5 # libnvinfer6=6.0.1-1+cuda10.1 #
#
# python -m pip install -q tensorflow
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Python 3.9.13
# E: Could not open lock file /var/lib/apt/lists/lock - open (13: Permission denied)
# E: Unable to lock directory /var/lib/apt/lists/
# W: Problem unlinking the file /var/cache/apt/pkgcache.bin - RemoveCaches (13: Permission denied)
# W: Problem unlinking the file /var/cache/apt/srcpkgcache.bin - RemoveCaches (13: Permission denied)
# E: Version '8.5.1' for 'tensorrt' was not found

# %%
# check TensorRT version
import tensorflow as tf
print("TensorFlow version: ", tf.version.VERSION)
print("TensorRT version: ")
# !dpkg -l | grep nvinfer
# Out:
# 2023-04-19 08:37:49.180321: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version:  2.12.0
# TensorRT version:
# ii  libnvinfer-bin                                    8.5.1-1+cuda11.8                                              amd64        TensorRT binaries
# ii  libnvinfer-dev                                    8.5.1-1+cuda11.8                                              amd64        TensorRT development libraries and headers
# ii  libnvinfer-plugin-dev                             8.5.1-1+cuda11.8                                              amd64        TensorRT plugin libraries
# ii  libnvinfer-plugin8                                8.5.1-1+cuda11.8                                              amd64        TensorRT plugin libraries
# ii  libnvinfer-samples                                8.5.1-1+cuda11.8                                              all          TensorRT samples
# ii  libnvinfer8                                       8.5.1-1+cuda11.8                                              amd64        TensorRT runtime libraries

# %% [markdown]
# A successfull TensorRT installation looks like:
#
# ```
# TensorFlow version:  2.0.0
# TensorRT version:
# ii  libnvinfer5   5.1.5-1+cuda10.1   amd64        TensorRT runtime libraries
# ```

# %% [markdown]
# ## Restart the Runtime
#
# **Note**
# After installing the required Python packages, you'll need to restart the Colab Runtime Engine (Menu > Runtime > Restart runtime...)
#
# ![Restart of the Colab Runtime Engine](https://drive.google.com/uc?id=1xnjAy2sxIymKhydkqb0RKzgVK9rh3teH)

# %% [markdown]
# ### Importing required libraries

# %%
# Re-run after Kernel restart
from __future__ import absolute_import, division, print_function, unicode_literals
import os
import time

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.python.compiler.tensorrt import trt_convert as trt
from tensorflow.python.saved_model import tag_constants
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import InceptionV3

from tensorflow.keras.applications.inception_v3 import (
    preprocess_input,
    decode_predictions,
)
# Out:
# 2023-04-19 09:10:45.668227: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Task 3: Load the Data and Pre-trained Model

# %% [markdown]
# ### Data
# We download several random images for testing from the Internet.

# %%
# !mkdir ./data
# !wget  -qO ./data/img0.JPG "https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/Golden_Retriever_Carlos_%2810581910556%29.jpg/640px-Golden_Retriever_Carlos_%2810581910556%29.jpg"
# !wget  -qO ./data/img1.JPG "https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/Red-shouldered_Hawk_%28Buteo_lineatus%29_-_Blue_Cypress_Lake%2C_Florida.jpg/407px-Red-shouldered_Hawk_%28Buteo_lineatus%29_-_Blue_Cypress_Lake%2C_Florida.jpg"
# !wget  -qO ./data/img2.JPG "https://upload.wikimedia.org/wikipedia/commons/thumb/2/28/Ostrich_male_RWD.jpg/636px-Ostrich_male_RWD.jpg"
# !wget  -qO ./data/img3.JPG "https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Working_pay_phone%2C_Jensen_Beach%2C_Florida%2C_September_4%2C_2012_001.JPG/360px-Working_pay_phone%2C_Jensen_Beach%2C_Florida%2C_September_4%2C_2012_001.JPG"

# %% [markdown]
# ### Model
#
# Thoughout this project, we will be using InceptionV3. Here we import the model from Keras.

# %%
model = InceptionV3(weights="imagenet")
# Out:
# 2023-04-19 08:19:45.775630: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45582 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:05:00.0, compute capability: 8.6

# %%
def show_predictions_four(model):
    for i in range(4):
        img_path = "./data/img%d.JPG" % i
        img = image.load_img(img_path, target_size=(299, 299))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        preds = model.predict(x)
        print(
            "{} - Predicted: {}".format(img_path, decode_predictions(preds, top=3)[0])
        )

        plt.subplot(2, 2, i + 1)
        plt.imshow(img)
        plt.axis("off")
        plt.title(decode_predictions(preds, top=3)[0][0][1])


show_predictions_four(model)
# Out:
# 2023-04-19 08:19:50.889386: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-04-19 08:19:51.705028: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1/1 [==============================] - 3s 3s/step
# ./data/img0.JPG - Predicted: [('n02099601', 'golden_retriever', 0.7292293), ('n02099712', 'Labrador_retriever', 0.12060873), ('n02104029', 'kuvasz', 0.02023787)]
# 1/1 [==============================] - 0s 29ms/step
# ./data/img1.JPG - Predicted: [('n01608432', 'kite', 0.98406476), ('n01807496', 'partridge', 0.0009508076), ('n01806567', 'quail', 0.00046490642)]
# 1/1 [==============================] - 0s 26ms/step
# ./data/img2.JPG - Predicted: [('n01518878', 'ostrich', 0.9312802), ('n02018795', 'bustard', 0.0020968476), ('n02437616', 'llama', 0.00083796354)]
# 1/1 [==============================] - 0s 26ms/step
# ./data/img3.JPG - Predicted: [('n03902125', 'pay-phone', 0.98752826), ('n03187595', 'dial_telephone', 0.009305394), ('n02977058', 'cash_machine', 4.111372e-05)]

# %% [markdown]
# When we benchmark our optimized TF-TRT models, they will be saved TensorFlow (not Keras) models. In order to have a fair comparison, here we save our Keras model as a TensorFlow model

# %%
# Save the entire model as a TensorFlow SavedModel.
# tf.saved_model.save(model, 'inceptionv3_saved_model')

# %%
# !saved_model_cli show --all --dir inceptionv3_saved_model
# Out:
# MetaGraphDef with tag-set: 'serve' contains the following SignatureDefs:
#
# signature_def['__saved_model_init_op']:
#   The given SavedModel SignatureDef contains the following input(s):
#   The given SavedModel SignatureDef contains the following output(s):
#     outputs['__saved_model_init_op'] tensor_info:
#         dtype: DT_INVALID
#         shape: unknown_rank
#         name: NoOp
#   Method name is:
#
# signature_def['serving_default']:
#   The given SavedModel SignatureDef contains the following input(s):
#     inputs['input_1'] tensor_info:
#         dtype: DT_FLOAT
#         shape: (-1, 299, 299, 3)
#         name: serving_default_input_1:0
#   The given SavedModel SignatureDef contains the following output(s):
#     outputs['predictions'] tensor_info:
#         dtype: DT_FLOAT
#         shape: (-1, 1000)
#         name: StatefulPartitionedCall:0
#   Method name is: tensorflow/serving/predict
# The MetaGraph with tag set ['serve'] contains the following ops: {'MatMul', 'ShardedFilename', 'DisableCopyOnRead', 'ReadVariableOp', 'ConcatV2', 'Select', 'Softmax', 'StaticRegexFullMatch', 'SaveV2', 'Placeholder', 'Relu', 'AvgPool', 'Conv2D', 'MergeV2Checkpoints', 'Identity', 'BiasAdd', 'Pack', 'FusedBatchNormV3', 'StringJoin', 'NoOp', 'Const', 'StatefulPartitionedCall', 'RestoreV2', 'AssignVariableOp', 'VarHandleOp', 'MaxPool', 'Mean'}
#
# Concrete Functions:
#   Function Name: '__call__'
#     Option #1
#       Callable with:
#         Argument #1
#           inputs: TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='inputs')
#         Argument #2
#           DType: bool
#           Value: True
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #2
#       Callable with:
#         Argument #1
#           input_1: TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_1')
#         Argument #2
#           DType: bool
#           Value: True
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #3
#       Callable with:
#         Argument #1
#           inputs: TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='inputs')
#         Argument #2
#           DType: bool
#           Value: False
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #4
#       Callable with:
#         Argument #1
#           input_1: TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_1')
#         Argument #2
#           DType: bool
#           Value: False
#         Argument #3
#           DType: NoneType
#           Value: None
#
#   Function Name: '_default_save_signature'
#     Option #1
#       Callable with:
#         Argument #1
#           input_1: TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_1')
#
#   Function Name: 'call_and_return_all_conditional_losses'
#     Option #1
#       Callable with:
#         Argument #1
#           inputs: TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='inputs')
#         Argument #2
#           DType: bool
#           Value: True
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #2
#       Callable with:
#         Argument #1
#           input_1: TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_1')
#         Argument #2
#           DType: bool
#           Value: True
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #3
#       Callable with:
#         Argument #1
#           input_1: TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_1')
#         Argument #2
#           DType: bool
#           Value: False
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #4
#       Callable with:
#         Argument #1
#           inputs: TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='inputs')
#         Argument #2
#           DType: bool
#           Value: False
#         Argument #3
#           DType: NoneType
#           Value: None

# %% [markdown]
# ## Task 4: Create Batched Input

# %% [markdown]
# Using **batch inference** to send many images to the GPU at once promotes **parallel processing** and improve throughput.

# %% [markdown]
# The `batch_input` helper function takes a batch_size, and returns a tensor with the preprocessed images.

# %%
# Re-run after Kernel restart
def batch_input(batch_size=8):
    batched_input = np.zeros((batch_size, 299, 299, 3), dtype=np.float32)
    for i in range(batch_size):
        img_path = './data/img%d.JPG'%(i%4)
        img = image.load_img(img_path, target_size =(299, 299))
        x = image.img_to_array(img)
        if i == 0:
            print('x', np.shape(x))
        x = np.expand_dims(x, axis=0)
        if i == 0:
            print('x', np.shape(x))
        x = preprocess_input(x)
        if i == 0:
            print(type(x))
        batched_input[i, :] = x
    # Batch into TF
    batched_input = tf.constant(batched_input)
    return batched_input
# Re-run after Kernel restart
batched_input = batch_input(batch_size=32)
# Out:
# x (299, 299, 3)
# x (1, 299, 299, 3)
# <class 'numpy.ndarray'>
# 2023-04-19 09:11:10.735865: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45581 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:05:00.0, compute capability: 8.6

# %%
# Out:
# x (299, 299, 3)
# x (1, 299, 299, 3)
# <class 'numpy.ndarray'>
# 2023-04-19 09:03:20.309188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45581 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:05:00.0, compute capability: 8.6

# %%
type(batched_input)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
batched_input.shape
# Out:
# TensorShape([32, 299, 299, 3])

# %% [markdown]
# ## Task 5: Load TensorFlow SavedModel

# %%
# Re-run after Kernel restart
def load_tf_saved_model(input_saved_model_dir):
    print(f"Loading saved model from {input_saved_model_dir}...")
    saved_model = tf.saved_model.load(
        export_dir=input_saved_model_dir, tags=[tag_constants.SERVING]
    )
    return saved_model

# %% [markdown]
# Here we load a previously saved InceptionV3 model.

# %%
# Re-run after Kernel restart
saved_model = load_tf_saved_model("inceptionv3_saved_model")
# Out:
# Loading saved model from inceptionv3_saved_model...

# %%
print("saved_model", saved_model)
# Out:
# saved_model <tensorflow.python.saved_model.load.Loader._recreate_base_user_object.<locals>._UserObject object at 0x7f20983fa8b0>

# %%
infer = saved_model.signatures["serving_default"]
print("infer.structured_outputs: \n", infer.structured_outputs)
# Out:
# infer.structured_outputs:
#  {'predictions': TensorSpec(shape=(None, 1000), dtype=tf.float32, name='predictions')}

# %% [markdown]
# ## Task 6: Get Baseline for Prediction Throughput and Accuracy
#
# ### Naive Inference with TensorFlow 2
#
# The following will serve as a baseline for prediction throughput and accuracy. Now we perform inference with the optimized graph, and after a warmup, time and calculate throughput.

# %% [markdown]
# The helper function `predict_and_benchmark_throughput` will use the passed in model to perform predictions on the passed in batched input over a number of runs. It measures and reports throughput, as well as time for ranges of runs.
#
# Due to GPU initialization operations, we do not want to profile against initial inference -- so we can set a number of warmup runs to perform prior to benchmarking.
#
# `predict_and_benchmark_throughput` returns the predictions for all images for all runs, after the warmup.

# %%
# Re-run after Kernel restart
def predict_and_benchmark_throughput(batched_input, infer, N_warmup_run=50, N_run=1000):
    elapsed_time = []
    all_preds = []
    batch_size = batched_input.shape[0]

    for i in range(N_warmup_run):
        labeling = infer(batched_input)
        preds = labeling["predictions"].numpy()

    for i in range(N_run):
        start_time = time.time()

        labeling = infer(batched_input)

        preds = labeling["predictions"].numpy()

        end_time = time.time()

        elapsed_time = np.append(elapsed_time, end_time - start_time)

        all_preds.append(preds)

        if i % 50 == 0:
            print(
                "Steps {}-{} average: {:4.1f}ms".format(
                    i, i + 50, (elapsed_time[-50:].mean()) * 1000
                )
            )

    print("Throughput: {:.0f} images/s".format(N_run * batch_size / elapsed_time.sum()))
    return all_preds

# %%
all_predictions = predict_and_benchmark_throughput(batched_input, infer)
# Out:
# Steps 0-50 average: 29.3ms
# Steps 50-100 average: 26.2ms
# Steps 100-150 average: 26.8ms
# Steps 150-200 average: 27.2ms
# Steps 200-250 average: 26.3ms
# Steps 250-300 average: 26.2ms
# Steps 300-350 average: 26.2ms
# Steps 350-400 average: 26.7ms
# Steps 400-450 average: 27.0ms
# Steps 450-500 average: 26.3ms
# Steps 500-550 average: 27.3ms
# Steps 550-600 average: 26.7ms
# Steps 600-650 average: 26.7ms
# Steps 650-700 average: 27.4ms
# Steps 700-750 average: 26.6ms
# Steps 750-800 average: 26.7ms
# Steps 800-850 average: 26.5ms
# Steps 850-900 average: 26.5ms
# Steps 900-950 average: 27.0ms
# Steps 950-1000 average: 27.0ms
# Throughput: 1184 images/s

# %% [markdown]
# ### Observe Accuracy
#
# **NOTE:** We are not so concerned in this project about the accuracy of our predictions per se, only that they remain consistent as we optimize our models.

# %%
# Re-run after Kernel restart
def show_predictions(model):
    img_path = "./data/img0.JPG"  # golden_retriever
    img = image.load_img(img_path, target_size=(299, 299))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    x = tf.constant(x)

    labeling = model(x)
    preds = labeling["predictions"].numpy()

    # decode the results into a list of tuples (class, description, probability)
    # (one such list for each sample in the batch)
    print("{} - Predicted: {}".format(img_path, decode_predictions(preds, top=3)[0]))
    plt.subplot(2, 2, 1)
    plt.imshow(img)
    plt.axis("off")
    plt.title(decode_predictions(preds, top=3)[0][0][1])

# %%
show_predictions(infer)
# Out:
# ./data/img0.JPG - Predicted: [('n02099601', 'golden_retriever', 0.7292293), ('n02099712', 'Labrador_retriever', 0.12060873), ('n02104029', 'kuvasz', 0.02023787)]

# %% [markdown]
# Before going to the next Task, please execute the cell below to restart the kernel and clear GPU memory.

# %%
import IPython
IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %% [markdown]
# ### Network Transformation
#
# TF-TRT performs several important transformations and optimizations to the neural network graph. First, layers with unused outputs are eliminated to avoid unnecessary computation. Next, where possible, convolution, bias, and ReLU layers are fused to form a single layer.
#
# **Figure (a)** shows a typical convolutional network before optimization and
#
# **Figure (c)** shows the result of this vertical layer fusion on the original network from Figure (a) (fused layers are labeled CBR). Layer fusion improves the efficiency of running TF-TRT networks on the GPU.
#
# **Figure (b)** Another transformation is horizontal layer fusion, or layer aggregation, along with the required division of aggregated layers to their respective outputs, as Figure (b) shows.
#
# Horizontal layer fusion improves performance by combining layers that take the same source tensor and apply the same operations with similar parameters, resulting in a single larger layer for higher computational efficiency. The example in Figure (b) shows the combination of 3 1×1 CBR layers from Figure (c) that take the same input into a single larger 1×1 CBR layer. Note that the output of this layer must be disaggregated to feed into the different subsequent layers from the original input graph.

# %% [markdown]
# *Source*: [Speed up TensorFlow Inference on GPUs with TensorRT](https://blog.tensorflow.org/2018/04/speed-up-tensorflow-inference-on-gpus-tensorRT.html)
#
# <div align="center">
#     <img width="700px" src='https://2.bp.blogspot.com/-nc-poLV8CNc/XhOI1wfgGjI/AAAAAAAACQI/3FlNTSKKrqMyTzR5XC5RCNnVuUY5EGmhQCLcBGAsYHQ/s1600/fig2.png' />
#     <p style="text-align: center;color:gray">Figure (a): An example convolutional  model with multiple convolutional and activation layers before optimization</p>
#     <p style="text-align: center;color:gray">Figure (c): Horizontal layer fusion</p>
# </div>

# %% [markdown]
# [Source](https://www.slideshare.net/cfregly/advanced-spark-and-tensorflow-meetup-20170506-reduced-precision-fp16-int8-inference-on-convolutional-neural-networks-with-tensorrt-and-nvidia-pascal-from-chris-gottbrath-nvidia): Advanced Spark and TensorFlow Meetup 2017-05-06 Reduced Precision (FP16, INT8) Inference on Convolutional Neural Networks with TensorRT and NVIDIA Pascal from Chris Gottbrath, Nvidia
#
# <div align="center">
#     <img width="600px" src='https://image.slidesharecdn.com/tensorrt-for-spark-tensorflow-meetup-final-170408190710/95/advanced-spark-and-tensorflow-meetup-20170506-reduced-precision-fp16-int8-inference-on-convolutional-neural-networks-with-tensorrt-and-nvidia-pascal-from-chris-gottbrath-nvidia-45-638.jpg' />
#     <p style="text-align: center;color:gray"> Figure (c). Horizontal layer fusion </p>
# </div>

# %% [markdown]
# When optimizing a TensorFlow model, TF-TRT can optimize either a subgraph or the entire graph definition. This capability allows the optimization procedure to be applied to the graph where possible and skip the non-supported graph segments. As a result, if the existing model contains a non-supported layer or operation, TensorFlow can still optimize the graph.

# %% [markdown]
# Please see the [TF-TRT User Guide](https://docs.nvidia.com/deeplearning/frameworks/tf-trt-user-guide/index.html#supported-ops) for a full list of supported operators.

# %% [markdown]
# ## TF-TRT Workflow:
#
# Below, you can see a typical workflow of TF-TRT:

# %% [markdown]
# [Source](https://medium.com/tensorflow/high-performance-inference-with-tensorrt-integration-c4d78795fbfe): High performance inference with TensorRT Integration
#
# <div align="center">
#     <img width="600px" src='https://miro.medium.com/max/875/1*hD_4k9bTEXnjuLHcaoFQRQ.png' />
# </div>
#
# <div align="center">
#     <img width="600px" src='https://miro.medium.com/max/875/1*DwxO-QF6Bz-H4aurRBIrjw.png' />
# </div>

# %% [markdown]
# We now turn to the syntax for this one additional Optimize with TF-TRT step.

# %% [markdown]
# ## Graph Conversion

# %% [markdown]
# To perform graph conversion, we use `TrtGraphConverterV2`, passing it the directory of a saved model, and any updates we wish to make to its conversion parameters.

# %% [markdown]
# ```python
# from tensorflow.python.compiler.tensorrt import trt_convert as trt
#
# trt.TrtGraphConverterV2(
#     input_saved_model_dir=None,
#     conversion_params=TrtConversionParams(precision_mode='FP32',
#                                           max_batch_size=1
#                                           minimum_segment_size=3,
#                                           max_workspace_size_bytes=8000000000,
#                                           use_calibration=True,
#                                           maximum_cached_engines=1,
#                                           is_dynamic_op=True,
#                                           rewriter_config_template=None,
#                                          )
# ```

# %% [markdown]
# ### Conversion Parameters
#
# Here is additional information about the most frequently adjusted conversion parameters.

# %% [markdown]
# * __precision_mode__: This parameter sets the precision mode; which can be one of FP32, FP16, or INT8. Precision lower than FP32, meaning FP16 and INT8, would improve the performance of inference. The FP16 mode uses Tensor Cores or half precision hardware instructions, if possible. The INT8 precision mode uses integer hardware instructions.
#
# * __max_batch_size__: This parameter is the maximum batch size for which TF-TRT will optimize. At runtime, a smaller batch size may be chosen, but, not a larger one.
#
# * __minimum_segment_size__: This parameter determines the minimum number of TensorFlow nodes in a TF-TRT engine, which means the TensorFlow subgraphs that have fewer nodes than this number will not be converted to TensorRT. Therefore, in general, smaller numbers such as 5 are preferred. This can also be used to change the minimum number of nodes in the optimized INT8 engines to change the final optimized graph to fine tune result accuracy.
#
# * __max_workspace_size_bytes__: TF-TRT operators often require temporary workspace. This parameter limits the maximum size that any layer in the network can use. If insufficient scratch is provided, it is possible that TF-TRT may not be able to find an implementation for a given layer.

# %% [markdown]
# # Task 7: Convert a TensorFlow saved model into a TF-TRT Float32 Graph
#
# Convert a TensorFlow saved model into a TF-TRT optimized graph using Float32 precision. We will use the optimized graph to make predictions and will benchmark its performance.

# %% [markdown]
# Only a few lines of code are needed to use TF-TRT
# ```python
# from tensorflow.python.compiler.tensorrt import trt_convert as trt
#
# conversion_params = trt.DEFAULT_TRT_CONVERSION_PARAMS._replace(
#   precision_mode=trt.TrtPrecisionMode.<FP16 or FP32>
#   max_workspace_bytes=8000000000
# )
#
# converter = trt.TrtGraphConverterV2(
#   input_saved_model_dir=input_saved_model_dir,
#   conversion_params=conversion_params
# )
#
# converter.convert()
#
# converter.save(output_saved_model_dir)
# ```

# %%
# Re-run after Kernel restart
def convert_to_trt_graph_and_save(
    precision_mode="float32",
    input_save_model_dir="inceptionv3_saved_model",
    calibration_data=batched_input,
):
    if precision_mode == "float32":
        precision_mode = trt.TrtPrecisionMode.FP32
        converted_save_suffix = "_TFTRT_FP32"
    elif precision_mode == "float16":
        precision_mode = trt.TrtPrecisionMode.FP16
        converted_save_suffix = "_TFTRT_FP16"
    elif precision_mode == "int8":
        precision_mode = trt.TrtPrecisionMode.INT8
        converted_save_suffix = "_TFTRT_INT8"
    else:
        raise ValueError('precision_mode is not recognize.')
    output_saved_model_dir = input_save_model_dir + converted_save_suffix
    conversion_params = trt.DEFAULT_TRT_CONVERSION_PARAMS._replace(
        precision_mode=precision_mode,
        max_workspace_size_bytes=int(8e9),
    )
    converter = trt.TrtGraphConverterV2(
        input_saved_model_dir=input_save_model_dir,
        conversion_params=conversion_params,
    )
    print(
        f"Converting {input_save_model_dir} to TF-TRT graph precision {precision_mode} ... "
    )
    if precision_mode == trt.TrtPrecisionMode.INT8:
        def calibration_input_fn():
            yield (calibration_data, )
        converter.convert(calibration_input_fn=calibration_input_fn)
    else:
        converter.convert()
    print(f"Saving convert mode {output_saved_model_dir}")
    converter.save(output_saved_model_dir=output_saved_model_dir)
    print("Complete")

# %%
convert_to_trt_graph_and_save(
    precision_mode="float32", input_save_model_dir="inceptionv3_saved_model"
)
# Out:
# INFO:tensorflow:Linked TensorRT version: (8, 4, 3)
# INFO:tensorflow:Loaded TensorRT version: (8, 5, 1)
# INFO:tensorflow:Loaded TensorRT 8.5.1 and linked TensorFlow against TensorRT 8.4.3. This is supported because TensorRT minor/patch upgrades are backward compatible.
# Converting inceptionv3_saved_model to TF-TRT graph precision FP32 ...
# 2023-04-19 08:48:06.660662: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2023-04-19 08:48:06.660768: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-04-19 08:48:06.662449: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45582 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:05:00.0, compute capability: 8.6
# INFO:tensorflow:Clearing prior device assignments in loaded saved model
# 2023-04-19 08:48:09.322742: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2023-04-19 08:48:09.322830: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-04-19 08:48:09.324533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45582 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:05:00.0, compute capability: 8.6
# 2023-04-19 08:48:10.154840: W tensorflow/compiler/tf2tensorrt/convert/trt_optimization_pass.cc:186] Calibration with FP32 or FP16 is not implemented. Falling back to use_calibration = False.Note that the default value of use_calibration is True.
# 2023-04-19 08:48:10.338761: W tensorflow/compiler/tf2tensorrt/segment/segment.cc:962]
#
# ################################################################################
# TensorRT unsupported/non-converted OP Report:
# 	- NoOp -> 2x
# 	- Identity -> 1x
# 	- Placeholder -> 1x
# --------------------------------------------------------------------------------
# 	- Total nonconverted OPs: 4
# 	- Total nonconverted OP Types: 3
# For more information see https://docs.nvidia.com/deeplearning/frameworks/tf-trt-user-guide/index.html#supported-ops.
# ################################################################################
#
# 2023-04-19 08:48:10.390814: W tensorflow/compiler/tf2tensorrt/segment/segment.cc:1290] The environment variable TF_TRT_MAX_ALLOWED_ENGINES=20 has no effect since there are only 1 TRT Engines with  at least minimum_segment_size=3 nodes.
# 2023-04-19 08:48:10.396462: I tensorflow/compiler/tf2tensorrt/convert/convert_graph.cc:799] Number of TensorRT candidate segments: 1
# 2023-04-19 08:48:10.563814: I tensorflow/compiler/tf2tensorrt/convert/convert_graph.cc:913] Replaced segment 0 consisting of 701 nodes by TRTEngineOp_000_000.
# Saving convert mode inceptionv3_saved_model_TFTRT_FP32
# INFO:tensorflow:Could not find TRTEngineOp_000_000 in TF-TRT cache. This can happen if build() is not called, which means TensorRT engines will be built and cached at runtime.
# INFO:tensorflow:Assets written to: inceptionv3_saved_model_TFTRT_FP32/assets
# Complete

# %%
saved_model_loaded = load_tf_saved_model(
    "inceptionv3_saved_model_TFTRT_FP32"
)
# Out:
# Loading saved model from inceptionv3_saved_model_TFTRT_FP32...

# %% [markdown]
# ## Task 8: Benchmark TF-TRT Float32

# %% [markdown]
# Load the optimized TF model.

# %%
saved_model_FP32 = saved_model_loaded

# %%
infer_FP32 = saved_model_FP32.signatures["serving_default"]

# %% [markdown]
# Perform inference with the optimized graph, and after a warmup, time and calculate throughput.

# %%
all_perf = predict_and_benchmark_throughput(batched_input, infer_FP32)
# Out:
# Steps 0-50 average: 36.2ms
# Steps 50-100 average: 34.1ms
# Steps 100-150 average: 33.8ms
# Steps 150-200 average: 35.1ms
# Steps 200-250 average: 34.0ms
# Steps 250-300 average: 34.0ms
# Steps 300-350 average: 35.3ms
# Steps 350-400 average: 34.4ms
# Steps 400-450 average: 34.0ms
# Steps 450-500 average: 34.3ms
# Steps 500-550 average: 34.2ms
# Steps 550-600 average: 34.3ms
# Steps 600-650 average: 34.9ms
# Steps 650-700 average: 34.6ms
# Steps 700-750 average: 34.7ms
# Steps 750-800 average: 35.1ms
# Steps 800-850 average: 34.2ms
# Steps 850-900 average: 35.1ms
# Steps 900-950 average: 35.6ms
# Steps 950-1000 average: 34.4ms
# Throughput: 926 images/s

# %%
print('TF model:')
show_predictions(infer)
print('TFRT model:')
show_predictions(infer_FP32)

# import IPython
# IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# TF model:
# ./data/img0.JPG - Predicted: [('n02099601', 'golden_retriever', 0.7294352), ('n02099712', 'Labrador_retriever', 0.120586894), ('n02104029', 'kuvasz', 0.020227905)]
# TFRT model:
# ./data/img0.JPG - Predicted: [('n02099601', 'golden_retriever', 0.72934514), ('n02099712', 'Labrador_retriever', 0.11994024), ('n02104029', 'kuvasz', 0.020271808)]

# %% [markdown]
# # Task 9: Convert to TF-TRT Float16 and Benchmark

# %% [markdown]
# In this task, you will update the convert_to_trt_graph_and_save function you worked with in the last task to be able to also perform conversion for Float16 precision.

# %%
convert_to_trt_graph_and_save(
    precision_mode="float16", input_save_model_dir="inceptionv3_saved_model"
)
# Out:
# INFO:tensorflow:Linked TensorRT version: (8, 4, 3)
# INFO:tensorflow:Loaded TensorRT version: (8, 5, 1)
# INFO:tensorflow:Loaded TensorRT 8.5.1 and linked TensorFlow against TensorRT 8.4.3. This is supported because TensorRT minor/patch upgrades are backward compatible.
# Converting inceptionv3_saved_model to TF-TRT graph precision FP16 ...
# 2023-04-17 10:24:25.779828: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2023-04-17 10:24:25.779929: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-04-17 10:24:25.781798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46101 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:05:00.0, compute capability: 8.6
# INFO:tensorflow:Clearing prior device assignments in loaded saved model
# 2023-04-17 10:24:27.702641: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2023-04-17 10:24:27.702723: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-04-17 10:24:27.704186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46101 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:05:00.0, compute capability: 8.6
# 2023-04-17 10:24:28.557230: W tensorflow/compiler/tf2tensorrt/convert/trt_optimization_pass.cc:186] Calibration with FP32 or FP16 is not implemented. Falling back to use_calibration = False.Note that the default value of use_calibration is True.
# 2023-04-17 10:24:28.850207: W tensorflow/compiler/tf2tensorrt/segment/segment.cc:962]
#
# ################################################################################
# TensorRT unsupported/non-converted OP Report:
# 	- NoOp -> 2x
# 	- Identity -> 1x
# 	- Placeholder -> 1x
# --------------------------------------------------------------------------------
# 	- Total nonconverted OPs: 4
# 	- Total nonconverted OP Types: 3
# For more information see https://docs.nvidia.com/deeplearning/frameworks/tf-trt-user-guide/index.html#supported-ops.
# ################################################################################
#
# 2023-04-17 10:24:28.904438: W tensorflow/compiler/tf2tensorrt/segment/segment.cc:1290] The environment variable TF_TRT_MAX_ALLOWED_ENGINES=20 has no effect since there are only 1 TRT Engines with  at least minimum_segment_size=3 nodes.
# 2023-04-17 10:24:28.910352: I tensorflow/compiler/tf2tensorrt/convert/convert_graph.cc:799] Number of TensorRT candidate segments: 1
# 2023-04-17 10:24:29.088378: I tensorflow/compiler/tf2tensorrt/convert/convert_graph.cc:913] Replaced segment 0 consisting of 701 nodes by TRTEngineOp_005_000.
# Saving convert mode inceptionv3_saved_model_TFTRT_FP16
# INFO:tensorflow:Could not find TRTEngineOp_005_000 in TF-TRT cache. This can happen if build() is not called, which means TensorRT engines will be built and cached at runtime.
# INFO:tensorflow:Assets written to: inceptionv3_saved_model_TFTRT_FP16/assets
# Complete

# %% [markdown]
# Load the optimized TF model.

# %%
saved_model_FP16 = load_tf_saved_model(
    "inceptionv3_saved_model_TFTRT_FP16"
)
# Out:
# Loading saved model from inceptionv3_saved_model_TFTRT_FP16...

# %%
infer_FP16 = saved_model_FP16.signatures["serving_default"] # type: ignore

# %% [markdown]
# Perform inference with the optimized graph, and after a warmup, time and calculate throughput.

# %%
all_perf = predict_and_benchmark_throughput(batched_input, infer_FP16)
print('FP16 shows 10 pect improvement than the original model.')
# Out:
# Steps 0-50 average: 25.4ms
# Steps 50-100 average: 23.3ms
# Steps 100-150 average: 31.5ms
# Steps 150-200 average: 23.3ms
# Steps 200-250 average: 23.4ms
# Steps 250-300 average: 24.2ms
# Steps 300-350 average: 23.7ms
# Steps 350-400 average: 24.1ms
# Steps 400-450 average: 24.3ms
# Steps 450-500 average: 23.9ms
# Steps 500-550 average: 23.9ms
# Steps 550-600 average: 23.9ms
# Steps 600-650 average: 24.0ms
# Steps 650-700 average: 23.9ms
# Steps 700-750 average: 23.6ms
# Steps 750-800 average: 23.9ms
# Steps 800-850 average: 23.2ms
# Steps 850-900 average: 23.2ms
# Steps 900-950 average: 23.6ms
# Steps 950-1000 average: 23.9ms
# Throughput: 1327 images/s

# %%
print('TFRT model FP32:')
show_predictions(infer_FP32)
print('TFRT model FP16:')
show_predictions(infer_FP16)
# Out:
# TFRT model FP32:
# ./data/img0.JPG - Predicted: [('n02099601', 'golden_retriever', 0.72934514), ('n02099712', 'Labrador_retriever', 0.11994024), ('n02104029', 'kuvasz', 0.020271808)]
# TFRT model FP16:
# ./data/img0.JPG - Predicted: [('n02099601', 'golden_retriever', 0.7294922), ('n02099712', 'Labrador_retriever', 0.1204834), ('n02104029', 'kuvasz', 0.020858765)]

# %% [markdown]
# Before going to the next Task, please execute the cell below to restart the kernel and clear GPU memory.

# %%
import IPython
IPython.Application.instance().kernel.do_shutdown(True)

# %% [markdown]
# ## Task 10: TF-TRT INT8 Model
#
# We will discuss how TF-TRT is able to optimize to use Int8 precision.

# %% [markdown]
# ## Benefits of Reduced Precision Inference

# %% [markdown]
# Typically, model training is performed using 32-bit floating point mathematics. Due to the backpropagation algorithm and weights updates, this high precision is necessary to allow for model convergence. Once trained, inference could be done in reduced precision (e.g. FP16) as the neural network architecture only requires a feed-forward network.
#
# Reducing numerical precision allows for a smaller model with faster inferencing time, lower memory requirements, and more throughput.
#
# Furthermore, recent NVIDIA GPUs are capable of executing 8-bit integer 4-element vector dot product instructions to accelerate deep neural network inference.

# %% [markdown]
# [Source](https://developer.nvidia.com/blog/int8-inference-autonomous-vehicles-tensorrt/): Fast INT8 Inference for Autonomous Vehicles with TensorRT 3
#
# <div align="center">
#     <img src='https://developer.nvidia.com/blog/wp-content/uploads/2017/12/dp4a-updated.png' />
#     <p style="text-align: center;color:gray"> Figure (d). The DP4A instruction: 4-element dot product with accumulation.</p>
# </div>

# %% [markdown]
# ## Reduced Dynamic Range of INT8

# %% [markdown]
# "While this new instruction provides faster computation, there is a significant challenge in representing weights and activations of deep neural networks in this reduced INT8 format. As *Table 1* shows, the dynamic range and granularity of representable values for INT8 is significantly limited compared to FP32 or FP16." [Source](https://developer.nvidia.com/blog/int8-inference-autonomous-vehicles-tensorrt/)

# %% [markdown]
# [Source](https://on-demand.gputechconf.com/gtc/2017/presentation/s7310-8-bit-inference-with-tensorrt.pdf): 8-bit Inference with TensorRT
#
# <div align="center">
#     <img src='https://kezunlin.me/images/posts/635233-20181119142909032-2033014099.png' />
#     <p style="text-align: center;color:gray"> Table 1. Dynamic range of FP32, FP16 and INT8.</p>
# </div>

# %% [markdown]
# ## TF-TRT INT8 Quantization

# %% [markdown]
# You might be wondering how it is possible to take a model which operates in 32 bit floating point precision, where you can represent billions of different numbers, and reduce that to only 8 bit integers which can only represent 256 possible values.
#
# The main reason is that, typically in deep learning, the values of weights and activations lie in very small ranges. So if we design our precious 8 bits to only represent this specific small range, we can usually maintain good accuracy while reducing the rounding error.
#
# The main challenge is to find the correct dynamic range of the inputs. TF-TRT uses a calibration process that minimizes the information loss when approximating the FP32 network with a limited 8-bit integer representation. In the next Task, you will see how to perform this calibration process.

# %% [markdown]
# [Source](https://blog.tensorflow.org/2019/06/high-performance-inference-with-TensorRT.html): High performance inference with TensorRT Integration
#
# <div align="center">
#     <img width="600px" src='https://2.bp.blogspot.com/-UiS1VGo7zwQ/XflUnggwnYI/AAAAAAAAB5g/yU5qOXVfWw0x8oYaKyRcd4AKsbBltU64ACLcBGAsYHQ/s1600/fig7.png' />
# </div>

# %% [markdown]
# Further quantization details: [https://developer.nvidia.com/gtc/2019/video/S9431/video](https://developer.nvidia.com/gtc/2019/video/S9431/video)

# %% [markdown]
# ### Calibration Dataset Considerations

# %% [markdown]
# When preparing the calibration dataset, you should capture the expected distribution of data in typical inference scenarios. You need to make sure that the calibration dataset covers all the expected scenarios, for example, clear weather, rainy day, night scenes, etc. When examining your own dataset, you should create a separate calibration dataset. The calibration dataset shouldn’t overlap with the training, validation or test datasets.

# %% [markdown]
# ## Task 11: Converting to TF-TRT INT8

# %% [markdown]
# You will convert a TensorFlow saved model into a TF-TRT optimized graph using INT8 precision.

# %%
convert_to_trt_graph_and_save(precision_mode='int8', input_save_model_dir='inceptionv3_saved_model')
# Out:
# INFO:tensorflow:Linked TensorRT version: (8, 4, 3)
# INFO:tensorflow:Loaded TensorRT version: (8, 5, 1)
# INFO:tensorflow:Loaded TensorRT 8.5.1 and linked TensorFlow against TensorRT 8.4.3. This is supported because TensorRT minor/patch upgrades are backward compatible.
# Converting inceptionv3_saved_model to TF-TRT graph precision INT8 ...
# 2023-04-19 09:39:10.788213: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2023-04-19 09:39:10.788304: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-04-19 09:39:10.789848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45581 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:05:00.0, compute capability: 8.6
# INFO:tensorflow:Clearing prior device assignments in loaded saved model
# 2023-04-19 09:39:12.933424: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2023-04-19 09:39:12.933517: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-04-19 09:39:12.935043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45581 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:05:00.0, compute capability: 8.6
# 2023-04-19 09:39:13.944908: W tensorflow/compiler/tf2tensorrt/segment/segment.cc:962]
#
# ################################################################################
# TensorRT unsupported/non-converted OP Report:
# 	- NoOp -> 2x
# 	- Identity -> 1x
# 	- Placeholder -> 1x
# --------------------------------------------------------------------------------
# 	- Total nonconverted OPs: 4
# 	- Total nonconverted OP Types: 3
# For more information see https://docs.nvidia.com/deeplearning/frameworks/tf-trt-user-guide/index.html#supported-ops.
# ################################################################################
#
# 2023-04-19 09:39:13.997062: W tensorflow/compiler/tf2tensorrt/segment/segment.cc:1290] The environment variable TF_TRT_MAX_ALLOWED_ENGINES=20 has no effect since there are only 1 TRT Engines with  at least minimum_segment_size=3 nodes.
# 2023-04-19 09:39:14.002820: I tensorflow/compiler/tf2tensorrt/convert/convert_graph.cc:799] Number of TensorRT candidate segments: 1
# 2023-04-19 09:39:14.169492: I tensorflow/compiler/tf2tensorrt/convert/convert_graph.cc:913] Replaced segment 0 consisting of 701 nodes by TRTEngineOp_002_000.
# 2023-04-19 09:41:11.622189: W tensorflow/compiler/tf2tensorrt/utils/trt_logger.cc:83] TF-TRT Warning: DefaultLogger TensorRT encountered issues when converting weights between types and that could affect accuracy.
# 2023-04-19 09:41:11.622213: W tensorflow/compiler/tf2tensorrt/utils/trt_logger.cc:83] TF-TRT Warning: DefaultLogger Check verbose logs for the list of affected weights.
# 2023-04-19 09:41:11.622220: W tensorflow/compiler/tf2tensorrt/utils/trt_logger.cc:83] TF-TRT Warning: DefaultLogger - 85 weights are affected by this issue: Detected subnormal FP16 values.
# 2023-04-19 09:41:11.622269: W tensorflow/compiler/tf2tensorrt/utils/trt_logger.cc:83] TF-TRT Warning: DefaultLogger - 40 weights are affected by this issue: Detected values less than smallest positive FP16 subnormal value and converted them to the FP16 minimum subnormalized value.
# Saving convert mode inceptionv3_saved_model_TFTRT_INT8
# INFO:tensorflow:Assets written to: inceptionv3_saved_model_TFTRT_INT8/assets
# Complete

# %% [markdown]
# ## Task 12: Benchmark TF-TRT INT8

# %% [markdown]
# You will use the optimized graph to make predictions and will benchmark its performance.

# %%
saved_model_INT8 = load_tf_saved_model(
    "inceptionv3_saved_model_TFTRT_INT8"
)
# Out:
# Loading saved model from inceptionv3_saved_model_TFTRT_INT8...

# %%
infer_INT8 = saved_model_INT8.signatures['serving_default']
all_preds = predict_and_benchmark_throughput(batched_input, infer_INT8)
# Out:
# Steps 0-50 average: 23.7ms
# Steps 50-100 average: 20.3ms
# Steps 100-150 average: 21.1ms
# Steps 150-200 average: 20.6ms
# Steps 200-250 average: 20.2ms
# Steps 250-300 average: 20.1ms
# Steps 300-350 average: 20.5ms
# Steps 350-400 average: 20.3ms
# Steps 400-450 average: 20.9ms
# Steps 450-500 average: 20.7ms
# Steps 500-550 average: 20.0ms
# Steps 550-600 average: 20.3ms
# Steps 600-650 average: 20.5ms
# Steps 650-700 average: 20.4ms
# Steps 700-750 average: 20.2ms
# Steps 750-800 average: 21.0ms
# Steps 800-850 average: 20.5ms
# Steps 850-900 average: 20.6ms
# Steps 900-950 average: 20.6ms
# Steps 950-1000 average: 20.4ms
# Throughput: 1562 images/s

# %%
# del saved_model_INT8

# %% [markdown]
# ## Conclusion
# In this notebook, we have demonstrated the process of creating TF-TRT FP32, FP16 and INT8 inference models from an original Keras FP32 model, as well as verify their speed and accuracy.
